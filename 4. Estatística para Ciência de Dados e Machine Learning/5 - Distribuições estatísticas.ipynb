# %% [markdown]
# # Distribuições estatísticas

# %%
import pandas as pd
import numpy as np
import statistics
import seaborn as srn
srn.set()
from scipy import stats

# %% [markdown]
# ## Variáveis contínuas

# %% [markdown]
# ## Distribuição normal - Gaussiana

# %%
dados_normal = stats.norm.rvs(size=1000, random_state=1)  # geração de numero aleatorios em formato gaussiano
dados_normal.shape
# Out:
# (1000,)

# %%
min(dados_normal), max(dados_normal)
# Out:
# (-3.053764380426305, 3.9586027040379634)

# %%
srn.histplot(dados_normal, kde=True, bins=20);

# %%
print(f'Média: {dados_normal.mean()}')
print(f'Mediana: {np.median(dados_normal)}')
print(f'Moda: {stats.mode(dados_normal)}')
print(f'Variância: {np.var(dados_normal)}')
print(f'Desvio Padrão: {np.std(dados_normal)}')
# Out:
# Média: 0.03881247615960185
# Mediana: 0.04129258886921605
# Moda: ModeResult(mode=array([-3.05376438]), count=array([1]))
# Variância: 0.9623691107920885
# Desvio Padrão: 0.9810041339322116

# %%
np.sum(((dados_normal >= np.std(dados_normal)) & (dados_normal <=np.std(dados_normal)+1)))
# Out:
# 148

# %%
np.sum(((dados_normal <= np.std(dados_normal)) & (dados_normal >=np.std(dados_normal)-1)))
# Out:
# 353

# %%
(148 + 353)/1000  # representam 50% da base de dados
# Out:
# 0.501

# %% [markdown]
# ### Base das alturas

# %%
# base ordenada
dados = np.array([126. , 129.5, 133. , 133. , 136.5, 136.5, 140. , 140. , 140. ,
                  140. , 143.5, 143.5, 143.5, 143.5, 143.5, 143.5, 147. , 147. ,
                  147. , 147. , 147. , 147. , 147. , 150.5, 150.5, 150.5, 150.5,
                  150.5, 150.5, 150.5, 150.5, 154. , 154. , 154. , 154. , 154. ,
                  154. , 154. , 154. , 154. , 157.5, 157.5, 157.5, 157.5, 157.5,
                  157.5, 157.5, 157.5, 157.5, 157.5, 161. , 161. , 161. , 161. ,
                  161. , 161. , 161. , 161. , 161. , 161. , 164.5, 164.5, 164.5,
                  164.5, 164.5, 164.5, 164.5, 164.5, 164.5, 168. , 168. , 168. ,
                  168. , 168. , 168. , 168. , 168. , 171.5, 171.5, 171.5, 171.5,
                  171.5, 171.5, 171.5, 175. , 175. , 175. , 175. , 175. , 175. ,
                  178.5, 178.5, 178.5, 178.5, 182. , 182. , 185.5, 185.5, 189., 192.5])
dados.shape
# Out:
# (100,)

# %%
print(f'Mínimo: {dados.min()}')
print(f'Máximo: {dados.max()}')
# Out:
# Mínimo: 126.0
# Máximo: 192.5

# %%
print(f'Média: {dados.mean()}')
print(f'Mediana: {np.median(dados)}')
print(f'Moda: {stats.mode(dados)}')
print(f'Variância: {np.var(dados)}')
print(f'Desvio Padrão: {np.std(dados)}')
# Out:
# Média: 159.25
# Mediana: 159.25
# Moda: ModeResult(mode=array([157.5]), count=array([10]))
# Variância: 186.3225
# Desvio Padrão: 13.65

# %%
srn.histplot(dados, kde=True, bins=10);

# %% [markdown]
# ## Enviesamento

# %%
dados_normal_positivo = stats.skewnorm.rvs(a=10, size=1000)
srn.histplot(dados_normal_positivo, kde=True, bins=10);

# %%
print(f'Média: {dados_normal_positivo.mean()}')
print(f'Mediana: {np.median(dados_normal_positivo)}')
print(f'Moda: {stats.mode(dados_normal_positivo)}')
print(f'Variância: {np.var(dados_normal_positivo)}')
print(f'Desvio Padrão: {np.std(dados_normal_positivo)}')
# Out:
# Média: 0.8161226861291909
# Mediana: 0.7058540891014049
# Moda: ModeResult(mode=array([-0.2651503]), count=array([1]))
# Variância: 0.35028204291672
# Desvio Padrão: 0.5918463000785931

# %%
dados_normal_negativo = stats.skewnorm.rvs(a=-10, size=1000)
srn.histplot(dados_normal_negativo, kde=True, bins=10);

# %%
print(f'Média: {dados_normal_negativo.mean()}')
print(f'Mediana: {np.median(dados_normal_negativo)}')
print(f'Moda: {stats.mode(dados_normal_negativo)}')
print(f'Variância: {np.var(dados_normal_negativo)}')
print(f'Desvio Padrão: {np.std(dados_normal_negativo)}')
# Out:
# Média: -0.804390582412316
# Mediana: -0.6884965219456564
# Moda: ModeResult(mode=array([-3.45440856]), count=array([1]))
# Variância: 0.3886346523036375
# Desvio Padrão: 0.6234056883792748

# %% [markdown]
# ## Distribuição normal - padronização

# %%
dados_normal_padronizada = np.random.standard_normal(size=1000)
srn.histplot(dados_normal_padronizada, kde=True, bins=10);

# %%
print(f'Mínimo: {dados_normal_padronizada.min()}')
print(f'Máximo: {dados_normal_padronizada.max()}')
# Out:
# Mínimo: -2.9293922665768477
# Máximo: 3.6763942439141317

# %%
print(f'Média: {dados_normal_padronizada.mean()}')
print(f'Mediana: {np.median(dados_normal_padronizada)}')
print(f'Moda: {stats.mode(dados_normal_padronizada)}')
print(f'Variância: {np.var(dados_normal_padronizada)}')
print(f'Desvio Padrão: {np.std(dados_normal_padronizada)}')
# Out:
# Média: -0.006481223627813712
# Mediana: -0.027366302179101593
# Moda: ModeResult(mode=array([-3.00304399]), count=array([1]))
# Variância: 1.0511425443929288
# Desvio Padrão: 1.0252524295962087

# %% [markdown]
# ### exemplo
#
# Padronizando a base

# %%
dados_padronizada = (dados - dados.mean())/np.std(dados)
dados_padronizada
# Out:
# array([-2.43589744, -2.17948718, -1.92307692, -1.92307692, -1.66666667,
#        -1.66666667, -1.41025641, -1.41025641, -1.41025641, -1.41025641,
#        -1.15384615, -1.15384615, -1.15384615, -1.15384615, -1.15384615,
#        -1.15384615, -0.8974359 , -0.8974359 , -0.8974359 , -0.8974359 ,
#        -0.8974359 , -0.8974359 , -0.8974359 , -0.64102564, -0.64102564,
#        -0.64102564, -0.64102564, -0.64102564, -0.64102564, -0.64102564,
#        -0.64102564, -0.38461538, -0.38461538, -0.38461538, -0.38461538,
#        -0.38461538, -0.38461538, -0.38461538, -0.38461538, -0.38461538,
#        -0.12820513, -0.12820513, -0.12820513, -0.12820513, -0.12820513,
#        -0.12820513, -0.12820513, -0.12820513, -0.12820513, -0.12820513,
#         0.12820513,  0.12820513,  0.12820513,  0.12820513,  0.12820513,
#         0.12820513,  0.12820513,  0.12820513,  0.12820513,  0.12820513,
#         0.38461538,  0.38461538,  0.38461538,  0.38461538,  0.38461538,
# ...

# %%
srn.histplot(dados_padronizada, kde=True, bins=10);

# %%
print(f'Média: {dados_padronizada.mean()}')
print(f'Mediana: {np.median(dados_padronizada)}')
print(f'Moda: {stats.mode(dados_padronizada)}')
print(f'Variância: {np.var(dados_padronizada)}')
print(f'Desvio Padrão: {np.std(dados_padronizada)}')
# Out:
# Média: 0.0
# Mediana: 0.0
# Moda: ModeResult(mode=array([-0.12820513]), count=array([10]))
# Variância: 0.9999999999999999
# Desvio Padrão: 0.9999999999999999

# %% [markdown]
# ## Teorema Central do Limite
#
# Diz que a medida que o tamanho da amostra aumenta, a distribuição amostral da sua média aproxima-se cada vez mais de uma distribuição normal.

# %%
alturas = np.random.randint(126, 192, 500)
print(alturas.shape)
srn.histplot(alturas, kde=True, bins=100);
# Out:
# (500,)

# %%
n=10000  # tamanho da amostra
medias = [np.mean(np.random.randint(126, 192, 500)) for _ in range(n)]
print(len(medias))
srn.histplot(medias, kde=True, bins=100);
# Out:
# 10000

# %% [markdown]
# ## Distribuição gama
#
# - Valores assimétricos à direita

# %%
from scipy.stats import gamma

# %%
dados_gama = gamma.rvs(a=3, size=1000)  # a é o ponto de decaimento
print(dados_gama.shape)
srn.histplot(dados_gama, kde=True, bins=100);
# Out:
# (1000,)

# %%
print(f'Mínimo: {dados_gama.min()}')
print(f'Máximo: {dados_gama.max()}')
# Out:
# Mínimo: 0.1925254856606613
# Máximo: 11.994313107810465

# %%
print(f'Média: {dados_gama.mean()}')
print(f'Mediana: {np.median(dados_gama)}')
print(f'Moda: {stats.mode(dados_gama)}')
print(f'Variância: {np.var(dados_gama)}')
print(f'Desvio Padrão: {np.std(dados_gama)}')
# Out:
# Média: 3.0229267522936847
# Mediana: 2.6747566802118534
# Moda: ModeResult(mode=array([0.19252549]), count=array([1]))
# Variância: 3.0056531706741434
# Desvio Padrão: 1.7336819692994858

# %% [markdown]
# ## Distribuição exponencial
#
# - Tipo de distribuição gama

# %%
from scipy.stats import expon

# %%
dados_exponencial = expon.rvs(size=1000) 
print(dados_exponencial.shape)
srn.histplot(dados_exponencial, kde=True, bins=100);
# Out:
# (1000,)

# %% [markdown]
# Sem valores para a esquerda

# %%
print(f'Mínimo: {dados_exponencial.min()}')
print(f'Máximo: {dados_exponencial.max()}')
# Out:
# Mínimo: 0.0016503801623676292
# Máximo: 7.87038996486965

# %%
print(f'Média: {dados_exponencial.mean()}')
print(f'Mediana: {np.median(dados_exponencial)}')
print(f'Moda: {stats.mode(dados_exponencial)}')
print(f'Variância: {np.var(dados_exponencial)}')
print(f'Desvio Padrão: {np.std(dados_exponencial)}')
# Out:
# Média: 1.0133982670510728
# Mediana: 0.6923321466108272
# Moda: ModeResult(mode=array([0.00165038]), count=array([1]))
# Variância: 1.0902876995365773
# Desvio Padrão: 1.0441684248896714
